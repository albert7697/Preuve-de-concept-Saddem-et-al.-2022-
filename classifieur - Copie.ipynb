# %% [markdown]
#                                                             AMSS-CSC
# <p align="center">
#                                                     <img src="./logo_ens.png">
# </p>

# %% [markdown]
# <div style="text-align: center;">
#     <H1>Techniques et outils pour la preuve de concepts</H1>
#     Alberic Junior DASSI FEUSSOUO
# </div>
#
#  <H3><i> Machine learning-based approach for online fault Diagnosis of Discrete Event System (Saddem et al. - 2022 )</H3>

# %% [markdown]
# # 3. Modèle de l'algorithme d'apprentissage automatique pour le diagnostic
# Dans cette partie, nous allons construire l'algorithme de LSTM pour le diagnostic, lui fournir les données formatées dans <a  href ="./preparation_des_donnees.ipynb"> la section précédente</a>, l'entrainer, le tester et évaluer ses performances. <br>
# Nous rappelons que notre modèle est un classifieur multi-classes. Au total, 8 classes sont considérées (C0 à C7). L’algorithme prend en entrée les données du système (au bon format) et renvoie en sortie la probabilité d’appartenance à l’une des classes (encodées), . <br>

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

class LSTMDiagnosticModel:
    """
    Modèle RNN-LSTM pour le diagnostic de défauts
    Basé sur la section 3.6 de l'article : "Training of the machine learning algorithm"
    """
    
    def __init__(self, n_steps, n_features, n_classes):
        """
        Paramètres:
        -----------
        n_steps : int
            Nombre de pas de temps (N=50 dans l'article)
        n_features : int
            Nombre de features par pas de temps (3 ou 4 selon version)
        n_classes : int
            Nombre de classes (8 : C0 à C7)
        """
        self.n_steps = n_steps
        self.n_features = n_features
        self.n_classes = n_classes
        self.model = None
        self.history = None
        
        print(f"Initialisation du modèle LSTM")
        print(f"  - Pas de temps (N) : {n_steps}")
        print(f"  - Features : {n_features}")
        print(f"  - Classes : {n_classes}")
    
    def build_model(self, lstm_units=[128, 64], dropout=0.3):
        """
        Construction de l'architecture RNN-LSTM
        
        Architecture inspirée de la Figure 3 de l'article :
        Input → LSTM layers → Dense → Softmax (8 neurones)
        
        Paramètres:
        -----------
        lstm_units : list
            Nombre de neurones par couche LSTM
        dropout : float
            Taux de dropout pour éviter le surapprentissage
        """
        print(f"\nConstruction du modèle...")
        print(f"  - Couches LSTM : {lstm_units}")
        print(f"  - Dropout : {dropout}")
        
        model = keras.Sequential([
            # Couche d'entrée
            layers.Input(shape=(self.n_steps, self.n_features)),
            
            # Première couche LSTM (retourne les séquences)
            layers.LSTM(lstm_units[0], return_sequences=True, name='LSTM_1'),
            layers.Dropout(dropout),
            
            # Deuxième couche LSTM
            layers.LSTM(lstm_units[1], return_sequences=False, name='LSTM_2'),
            layers.Dropout(dropout),
            
            # Couche Dense intermédiaire
            layers.Dense(32, activation='relu', name='Dense_1'),
            layers.Dropout(dropout/2),
            
            # Couche de sortie avec Softmax (8 neurones pour 8 classes)
            # Section 3.6 : "uses the softmax function to activate the last layer"
            layers.Dense(self.n_classes, activation='softmax', name='Output')
        ])
        
        self.model = model
        
        print("\n" + "="*70)
        print("ARCHITECTURE DU MODÈLE")
        print("="*70)
        self.model.summary()
        
        return model
    
    def compile_model(self, learning_rate=0.001):
        """
        Compilation du modèle
        
        Section 4.2 : "For the error function, we use the 
        Categorical Cross-Entropy (CCE) function"
        """
        print(f"\nCompilation du modèle...")
        print(f"  - Fonction de perte : Categorical Crossentropy (CCE)")
        print(f"  - Optimiseur : Adam")
        print(f"  - Learning rate : {learning_rate}")
        
        self.model.compile(
            optimizer=keras.optimizers.Adam(learning_rate=learning_rate),
            loss='sparse_categorical_crossentropy',  # CCE pour labels entiers
            metrics=['accuracy']
        )
        
        print("✓ Modèle compilé")
    
    def train(self, X_train, y_train, X_val, y_val, 
              epochs=100, batch_size=32, verbose=1):
        """
        Entraînement du modèle avec validation
        
        Section 3.2 : "We use cross-validation (CV for short)"
        Ici on utilise une simple validation holdout pour commencer
        """
        print("\n" + "="*70)
        print("ENTRAÎNEMENT DU MODÈLE")
        print("="*70)
        print(f"Epochs : {epochs}")
        print(f"Batch size : {batch_size}")
        print(f"Échantillons d'entraînement : {len(X_train)}")
        print(f"Échantillons de validation : {len(X_val)}")
        
        # Callbacks pour améliorer l'entraînement
        callbacks = [
            # Arrêt précoce si pas d'amélioration
            EarlyStopping(
                monitor='val_loss',
                patience=15,
                restore_best_weights=True,
                verbose=1
            ),
            
            # Réduction du learning rate
            ReduceLROnPlateau(
                monitor='val_loss',
                factor=0.5,
                patience=5,
                min_lr=1e-7,
                verbose=1
            ),
            
            # Sauvegarde du meilleur modèle
            ModelCheckpoint(
                'best_model.keras',
                monitor='val_accuracy',
                save_best_only=True,
                verbose=1
            )
        ]
        
        # Entraînement
        self.history = self.model.fit(
            X_train, y_train,
            validation_data=(X_val, y_val),
            epochs=epochs,
            batch_size=batch_size,
            callbacks=callbacks,
            verbose=verbose
        )
        
        print("\n✓ Entraînement terminé")
        
        return self.history
    
    def plot_training_history(self):
        """
        Visualise l'historique d'entraînement
        Correspond aux Figures 8 et 9 de l'article
        """
        if self.history is None:
            print("Aucun historique d'entraînement disponible")
            return
        
        fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))
        
        # Graphique 1 : Loss (fonction d'erreur)
        # Figure 8 de l'article : "Evolution of the error function"
        ax1.plot(self.history.history['loss'], label='Train Loss', linewidth=2)
        ax1.plot(self.history.history['val_loss'], label='Validation Loss', linewidth=2)
        ax1.set_xlabel('Epoch', fontsize=12)
        ax1.set_ylabel('Loss (CCE)', fontsize=12)
        ax1.set_title('Évolution de la fonction d\'erreur', fontsize=14, fontweight='bold')
        ax1.legend()
        ax1.grid(True, alpha=0.3)
        
        # Graphique 2 : Accuracy
        # Figure 9 de l'article : "Evolution of the average accuracy"
        ax2.plot(self.history.history['accuracy'], label='Train Accuracy', linewidth=2)
        ax2.plot(self.history.history['val_accuracy'], label='Validation Accuracy', linewidth=2)
        ax2.set_xlabel('Epoch', fontsize=12)
        ax2.set_ylabel('Accuracy', fontsize=12)
        ax2.set_title('Évolution de l\'accuracy moyenne', fontsize=14, fontweight='bold')
        ax2.legend()
        ax2.grid(True, alpha=0.3)
        
        plt.tight_layout()
        plt.savefig('training_history.png', dpi=300, bbox_inches='tight')
        plt.show()
        
        # Afficher les meilleurs résultats
        best_epoch = np.argmax(self.history.history['val_accuracy'])
        print("\n" + "="*70)
        print("MEILLEURS RÉSULTATS")
        print("="*70)
        print(f"Meilleur epoch : {best_epoch + 1}")
        print(f"Train Accuracy : {self.history.history['accuracy'][best_epoch]:.4f}")
        print(f"Val Accuracy : {self.history.history['val_accuracy'][best_epoch]:.4f}")
        print(f"Train Loss : {self.history.history['loss'][best_epoch]:.4f}")
        print(f"Val Loss : {self.history.history['val_loss'][best_epoch]:.4f}")
    
    def evaluate(self, X_test, y_test, class_names):
        """
        Évaluation sur le jeu de test
        """
        print("\n" + "="*70)
        print("ÉVALUATION SUR LE JEU DE TEST")
        print("="*70)
        
        # Prédictions
        y_pred_probs = self.model.predict(X_test, verbose=0)
        y_pred = np.argmax(y_pred_probs, axis=1)
        
        # Accuracy globale
        test_loss, test_acc = self.model.evaluate(X_test, y_test, verbose=0)
        print(f"\nTest Loss : {test_loss:.4f}")
        print(f"Test Accuracy : {test_acc:.4f}")
        
        # Rapport de classification détaillé
        print("\n" + "="*70)
        print("RAPPORT DE CLASSIFICATION")
        print("="*70)
        print(classification_report(y_test, y_pred, target_names=class_names))
        
        return y_pred, y_pred_probs
    
    def plot_confusion_matrix(self, y_test, y_pred, class_names):
        """
        Matrice de confusion
        Figure 10 de l'article : "The average of normalized multi-class confusion matrix"
        """
        # Calculer la matrice de confusion
        cm = confusion_matrix(y_test, y_pred)
        cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        
        # Visualisation
        plt.figure(figsize=(10, 8))
        sns.heatmap(cm_normalized, annot=True, fmt='.2f', cmap='Blues',
                    xticklabels=class_names, yticklabels=class_names,
                    cbar_kws={'label': 'Proportion'})
        plt.xlabel('Classe prédite', fontsize=12)
        plt.ylabel('Classe réelle', fontsize=12)
        plt.title('Matrice de confusion normalisée', fontsize=14, fontweight='bold')
        plt.tight_layout()
        plt.savefig('confusion_matrix.png', dpi=300, bbox_inches='tight')
        plt.show()
        
        return cm, cm_normalized
    
    def calculate_metrics(self, cm):
        """
        Calcule les métriques par classe
        Section 3.6 : Precision et Recall
        
        Precision_i = TP_i / (TP_i + FP_i)
        Recall_i = TP_i / (TP_i + FN_i)
        """
        n_classes = cm.shape[0]
        
        precision = []
        recall = []
        
        for i in range(n_classes):
            TP = cm[i, i]
            FP = cm[:, i].sum() - TP
            FN = cm[i, :].sum() - TP
            
            prec = TP / (TP + FP) if (TP + FP) > 0 else 0
            rec = TP / (TP + FN) if (TP + FN) > 0 else 0
            
            precision.append(prec)
            recall.append(rec)
        
        return precision, recall
    
    def save_model(self, filepath='lstm_diagnostic_model.keras'):
        """
        Sauvegarde le modèle entraîné
        """
        self.model.save(filepath)
        print(f"\n✓ Modèle sauvegardé : {filepath}")
    
    def load_model(self, filepath='lstm_diagnostic_model.keras'):
        """
        Charge un modèle pré-entraîné
        """
        self.model = keras.models.load_model(filepath)
        print(f"✓ Modèle chargé : {filepath}")


# ==== DÉMONSTRATION ====
if __name__ == "__main__":
    print("="*70)
    print("MODÈLE RNN-LSTM POUR LE DIAGNOSTIC DE DÉFAUTS")
    print("="*70)
    
    # 1. Charger les données préparées
    print("\nChargement des données...")
    data = np.load('prepared_data.npz',allow_pickle=True)
    X_train = data['X_train'].astype("float32")
    X_val = data['X_val'].astype("float32")
    X_test = data['X_test'].astype("float32")
    y_train = data['y_train'].astype("float64")
    y_val = data['y_val'].astype("float64")
    y_test = data['y_test'].astype("float64")
    
    print(f"✓ Données chargées")
    print(f"  X_train shape : {X_train.shape}")
    print(f"  y_train shape : {y_train.shape}")
    
    # 2. Créer et construire le modèle
    n_steps = X_train.shape[1]  # 50
    n_features = X_train.shape[2]  # 4 (avec durées) ou 3 (sans)
    n_classes = len(np.unique(y_train))  # 8
    
    model = LSTMDiagnosticModel(n_steps, n_features, n_classes)
    model.build_model(lstm_units=[128, 64], dropout=0.3)
    model.compile_model(learning_rate=0.001)
    
    # 3. Entraîner le modèle
    history = model.train(
        X_train, y_train,
        X_val, y_val,
        epochs=100,
        batch_size=32,
        verbose=1
    )
    
    # 4. Visualiser l'historique d'entraînement
    model.plot_training_history()
    
    # 5. Évaluer sur le jeu de test
    class_names = ['C0', 'C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'C7']
    y_pred, y_pred_probs = model.evaluate(X_test, y_test, class_names)
    
    # 6. Matrice de confusion
    cm, cm_normalized = model.plot_confusion_matrix(y_test, y_pred, class_names)
    
    # 7. Métriques par classe
    precision, recall = model.calculate_metrics(cm)
    
    print("\n" + "="*70)
    print("MÉTRIQUES PAR CLASSE")
    print("="*70)
    print(f"{'Classe':<10} {'Precision':<12} {'Recall':<12}")
    print("-" * 35)
    for i, name in enumerate(class_names):
        print(f"{name:<10} {precision[i]:<12.4f} {recall[i]:<12.4f}")
    
    # 8. Sauvegarder le modèle
    model.save_model('lstm_diagnostic_model.keras')
    
    print("\n" + "="*70)
    print("ENTRAÎNEMENT TERMINÉ AVEC SUCCÈS !")
    print("="*70)
# Out:
# ======================================================================
# MODÈLE RNN-LSTM POUR LE DIAGNOSTIC DE DÉFAUTS
# ======================================================================
#
# Chargement des données...
# ✓ Données chargées
#   X_train shape : (690, 50, 4)
#   y_train shape : (690,)
# Initialisation du modèle LSTM
#   - Pas de temps (N) : 50
#   - Features : 4
#   - Classes : 8
#
# Construction du modèle...
#   - Couches LSTM : [128, 64]
#   - Dropout : 0.3
#
# ======================================================================
# ARCHITECTURE DU MODÈLE
# ======================================================================
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ LSTM_1 (LSTM)                        │ (None, 50, 128)             │          68,096 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 50, 128)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ LSTM_2 (LSTM)                        │ (None, 64)                  │          49,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Dense_1 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Output (Dense)                       │ (None, 8)                   │             264 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 119,848 (468.16 KB)
#  Trainable params: 119,848 (468.16 KB)
#  Non-trainable params: 0 (0.00 B)
# Compilation du modèle...
#   - Fonction de perte : Categorical Crossentropy (CCE)
#   - Optimiseur : Adam
#   - Learning rate : 0.001
# ✓ Modèle compilé
#
# ======================================================================
# ENTRAÎNEMENT DU MODÈLE
# ======================================================================
# Epochs : 100
# Batch size : 32
# Échantillons d'entraînement : 690
# Échantillons de validation : 230
# Epoch 1/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.4933 - loss: 1.8507
# Epoch 1: val_accuracy improved from None to 0.58696, saving model to best_model.keras
#
# Epoch 1: finished saving model to best_model.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - accuracy: 0.5536 - loss: 1.7046 - val_accuracy: 0.5870 - val_loss: 1.4321 - learning_rate: 0.0010
# Epoch 2/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6011 - loss: 1.4534
# Epoch 2: val_accuracy improved from 0.58696 to 0.67826, saving model to best_model.keras
#
# Epoch 2: finished saving model to best_model.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.6203 - loss: 1.3932 - val_accuracy: 0.6783 - val_loss: 1.2428 - learning_rate: 0.0010
# Epoch 3/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6851 - loss: 1.2151
# Epoch 3: val_accuracy did not improve from 0.67826
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - accuracy: 0.6812 - loss: 1.1689 - val_accuracy: 0.6696 - val_loss: 1.0371 - learning_rate: 0.0010
# Epoch 4/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6947 - loss: 1.0150
# Epoch 4: val_accuracy improved from 0.67826 to 0.78696, saving model to best_model.keras
#
# Epoch 4: finished saving model to best_model.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.7058 - loss: 0.9581 - val_accuracy: 0.7870 - val_loss: 0.8853 - learning_rate: 0.0010
# Epoch 5/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7617 - loss: 0.7973
# Epoch 5: val_accuracy improved from 0.78696 to 0.80435, saving model to best_model.keras
#
# Epoch 5: finished saving model to best_model.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.7696 - loss: 0.7320 - val_accuracy: 0.8043 - val_loss: 0.5621 - learning_rate: 0.0010
# Epoch 6/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8364 - loss: 0.5604
# Epoch 6: val_accuracy improved from 0.80435 to 0.89565, saving model to best_model.keras
#
# Epoch 6: finished saving model to best_model.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.8304 - loss: 0.5596 - val_accuracy: 0.8957 - val_loss: 0.4297 - learning_rate: 0.0010
# Epoch 7/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.8373 - loss: 0.4774
# Epoch 7: val_accuracy improved from 0.89565 to 0.90435, saving model to best_model.keras
#
# Epoch 7: finished saving model to best_model.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.8391 - loss: 0.4783 - val_accuracy: 0.9043 - val_loss: 0.3332 - learning_rate: 0.0010
# Epoch 8/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.8557 - loss: 0.4615
# Epoch 8: val_accuracy improved from 0.90435 to 0.90870, saving model to best_model.keras
#
# Epoch 8: finished saving model to best_model.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8652 - loss: 0.4143 - val_accuracy: 0.9087 - val_loss: 0.3140 - learning_rate: 0.0010
# Epoch 9/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8828 - loss: 0.3311
# Epoch 9: val_accuracy improved from 0.90870 to 0.91304, saving model to best_model.keras
#
# Epoch 9: finished saving model to best_model.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - accuracy: 0.8841 - loss: 0.3571 - val_accuracy: 0.9130 - val_loss: 0.2659 - learning_rate: 0.0010
# Epoch 10/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8812 - loss: 0.3557
# Epoch 10: val_accuracy improved from 0.91304 to 0.92609, saving model to best_model.keras
#
# Epoch 10: finished saving model to best_model.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.8870 - loss: 0.3470 - val_accuracy: 0.9261 - val_loss: 0.2919 - learning_rate: 0.0010
# Epoch 11/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8797 - loss: 0.3465
# Epoch 11: val_accuracy did not improve from 0.92609
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.8391 - loss: 0.4722 - val_accuracy: 0.8304 - val_loss: 0.4957 - learning_rate: 0.0010
# Epoch 12/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8141 - loss: 0.5380
# Epoch 12: val_accuracy did not improve from 0.92609
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8217 - loss: 0.5427 - val_accuracy: 0.8696 - val_loss: 0.3446 - learning_rate: 0.0010
# Epoch 13/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8809 - loss: 0.4042
# Epoch 13: val_accuracy did not improve from 0.92609
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.8783 - loss: 0.3782 - val_accuracy: 0.9043 - val_loss: 0.2813 - learning_rate: 0.0010
# Epoch 14/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8638 - loss: 0.3538
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 14: val_accuracy did not improve from 0.92609
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.8710 - loss: 0.3273 - val_accuracy: 0.8957 - val_loss: 0.2761 - learning_rate: 0.0010
# Epoch 15/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9014 - loss: 0.2942
# Epoch 15: val_accuracy did not improve from 0.92609
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.9116 - loss: 0.2726 - val_accuracy: 0.9087 - val_loss: 0.2286 - learning_rate: 5.0000e-04
# Epoch 16/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.8946 - loss: 0.2726
# Epoch 16: val_accuracy did not improve from 0.92609
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.9072 - loss: 0.2542 - val_accuracy: 0.9217 - val_loss: 0.2334 - learning_rate: 5.0000e-04
# Epoch 17/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9235 - loss: 0.2317
# Epoch 17: val_accuracy improved from 0.92609 to 0.93043, saving model to best_model.keras
#
# Epoch 17: finished saving model to best_model.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.9159 - loss: 0.2413 - val_accuracy: 0.9304 - val_loss: 0.2358 - learning_rate: 5.0000e-04
# Epoch 18/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9134 - loss: 0.2528
# Epoch 18: val_accuracy did not improve from 0.93043
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.9130 - loss: 0.2488 - val_accuracy: 0.9304 - val_loss: 0.2113 - learning_rate: 5.0000e-04
# Epoch 19/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9098 - loss: 0.2414
# Epoch 19: val_accuracy did not improve from 0.93043
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.9116 - loss: 0.2378 - val_accuracy: 0.9217 - val_loss: 0.2174 - learning_rate: 5.0000e-04
# Epoch 20/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9140 - loss: 0.2174
# Epoch 20: val_accuracy improved from 0.93043 to 0.93913, saving model to best_model.keras
#
# Epoch 20: finished saving model to best_model.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.9217 - loss: 0.2230 - val_accuracy: 0.9391 - val_loss: 0.1884 - learning_rate: 5.0000e-04
# Epoch 21/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9252 - loss: 0.2014
# Epoch 21: val_accuracy did not improve from 0.93913
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.9232 - loss: 0.2035 - val_accuracy: 0.9391 - val_loss: 0.2090 - learning_rate: 5.0000e-04
# Epoch 22/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9150 - loss: 0.2137
# Epoch 22: val_accuracy did not improve from 0.93913
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.9203 - loss: 0.2032 - val_accuracy: 0.9348 - val_loss: 0.2070 - learning_rate: 5.0000e-04
# Epoch 23/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9358 - loss: 0.1994
# Epoch 23: val_accuracy did not improve from 0.93913
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.9304 - loss: 0.2064 - val_accuracy: 0.9087 - val_loss: 0.2201 - learning_rate: 5.0000e-04
# Epoch 24/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9431 - loss: 0.2170
# Epoch 24: val_accuracy improved from 0.93913 to 0.94783, saving model to best_model.keras
#
# Epoch 24: finished saving model to best_model.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.9435 - loss: 0.1950 - val_accuracy: 0.9478 - val_loss: 0.1934 - learning_rate: 5.0000e-04
# Epoch 25/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9164 - loss: 0.2107
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 25: val_accuracy did not improve from 0.94783
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.9217 - loss: 0.2086 - val_accuracy: 0.9261 - val_loss: 0.2493 - learning_rate: 5.0000e-04
# Epoch 26/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9233 - loss: 0.1866
# Epoch 26: val_accuracy improved from 0.94783 to 0.95652, saving model to best_model.keras
#
# Epoch 26: finished saving model to best_model.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.9217 - loss: 0.2102 - val_accuracy: 0.9565 - val_loss: 0.1716 - learning_rate: 2.5000e-04
# Epoch 27/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9434 - loss: 0.1869
# Epoch 27: val_accuracy did not improve from 0.95652
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.9522 - loss: 0.1675 - val_accuracy: 0.9435 - val_loss: 0.1781 - learning_rate: 2.5000e-04
# Epoch 28/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9256 - loss: 0.1864
# Epoch 28: val_accuracy did not improve from 0.95652
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.9319 - loss: 0.1791 - val_accuracy: 0.9348 - val_loss: 0.1705 - learning_rate: 2.5000e-04
# Epoch 29/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9602 - loss: 0.1461
# Epoch 29: val_accuracy did not improve from 0.95652
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.9507 - loss: 0.1552 - val_accuracy: 0.9478 - val_loss: 0.1577 - learning_rate: 2.5000e-04
# Epoch 30/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9530 - loss: 0.1495
# Epoch 30: val_accuracy did not improve from 0.95652
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.9493 - loss: 0.1540 - val_accuracy: 0.9391 - val_loss: 0.1585 - learning_rate: 2.5000e-04
# Epoch 31/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9450 - loss: 0.1491
# Epoch 31: val_accuracy did not improve from 0.95652
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.9464 - loss: 0.1476 - val_accuracy: 0.9565 - val_loss: 0.1679 - learning_rate: 2.5000e-04
# Epoch 32/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9576 - loss: 0.1403
# Epoch 32: val_accuracy did not improve from 0.95652
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.9493 - loss: 0.1646 - val_accuracy: 0.9391 - val_loss: 0.1645 - learning_rate: 2.5000e-04
# Epoch 33/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9376 - loss: 0.1619
# Epoch 33: val_accuracy did not improve from 0.95652
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.9493 - loss: 0.1575 - val_accuracy: 0.9435 - val_loss: 0.1543 - learning_rate: 2.5000e-04
# Epoch 34/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9638 - loss: 0.1366
# Epoch 34: val_accuracy did not improve from 0.95652
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.9536 - loss: 0.1495 - val_accuracy: 0.9478 - val_loss: 0.1543 - learning_rate: 2.5000e-04
# Epoch 35/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9571 - loss: 0.1290
# Epoch 35: val_accuracy did not improve from 0.95652
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.9536 - loss: 0.1490 - val_accuracy: 0.9478 - val_loss: 0.1584 - learning_rate: 2.5000e-04
# Epoch 36/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9504 - loss: 0.1676
# Epoch 36: val_accuracy did not improve from 0.95652
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.9464 - loss: 0.1694 - val_accuracy: 0.9435 - val_loss: 0.1752 - learning_rate: 2.5000e-04
# Epoch 37/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9529 - loss: 0.1389
# Epoch 37: val_accuracy did not improve from 0.95652
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.9507 - loss: 0.1401 - val_accuracy: 0.9522 - val_loss: 0.1444 - learning_rate: 2.5000e-04
# Epoch 38/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9585 - loss: 0.1402
# Epoch 38: val_accuracy did not improve from 0.95652
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.9652 - loss: 0.1257 - val_accuracy: 0.9565 - val_loss: 0.1371 - learning_rate: 2.5000e-04
# Epoch 39/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9483 - loss: 0.1580
# Epoch 39: val_accuracy did not improve from 0.95652
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.9565 - loss: 0.1358 - val_accuracy: 0.9522 - val_loss: 0.1454 - learning_rate: 2.5000e-04
# Epoch 40/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9624 - loss: 0.1300
# Epoch 40: val_accuracy improved from 0.95652 to 0.96087, saving model to best_model.keras
#
# Epoch 40: finished saving model to best_model.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.9594 - loss: 0.1337 - val_accuracy: 0.9609 - val_loss: 0.1242 - learning_rate: 2.5000e-04
# Epoch 41/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9486 - loss: 0.1353
# Epoch 41: val_accuracy improved from 0.96087 to 0.96957, saving model to best_model.keras
#
# Epoch 41: finished saving model to best_model.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.9623 - loss: 0.1254 - val_accuracy: 0.9696 - val_loss: 0.1206 - learning_rate: 2.5000e-04
# Epoch 42/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9703 - loss: 0.1299
# Epoch 42: val_accuracy did not improve from 0.96957
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.9710 - loss: 0.1264 - val_accuracy: 0.9652 - val_loss: 0.1305 - learning_rate: 2.5000e-04
# Epoch 43/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9608 - loss: 0.1218
# Epoch 43: val_accuracy improved from 0.96957 to 0.97391, saving model to best_model.keras
#
# Epoch 43: finished saving model to best_model.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.9681 - loss: 0.1145 - val_accuracy: 0.9739 - val_loss: 0.1234 - learning_rate: 2.5000e-04
# Epoch 44/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9560 - loss: 0.1326
# Epoch 44: val_accuracy did not improve from 0.97391
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.9623 - loss: 0.1232 - val_accuracy: 0.9609 - val_loss: 0.1385 - learning_rate: 2.5000e-04
# Epoch 45/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9743 - loss: 0.0901
# Epoch 45: val_accuracy did not improve from 0.97391
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.9667 - loss: 0.1093 - val_accuracy: 0.9478 - val_loss: 0.1325 - learning_rate: 2.5000e-04
# Epoch 46/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9731 - loss: 0.0944
# Epoch 46: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 46: val_accuracy did not improve from 0.97391
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.9681 - loss: 0.1058 - val_accuracy: 0.9652 - val_loss: 0.1308 - learning_rate: 2.5000e-04
# Epoch 47/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9645 - loss: 0.1150
# Epoch 47: val_accuracy did not improve from 0.97391
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.9696 - loss: 0.1101 - val_accuracy: 0.9696 - val_loss: 0.1195 - learning_rate: 1.2500e-04
# Epoch 48/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9796 - loss: 0.1002
# Epoch 48: val_accuracy did not improve from 0.97391
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.9681 - loss: 0.1079 - val_accuracy: 0.9522 - val_loss: 0.1247 - learning_rate: 1.2500e-04
# Epoch 49/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9699 - loss: 0.0933
# Epoch 49: val_accuracy did not improve from 0.97391
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.9667 - loss: 0.1028 - val_accuracy: 0.9652 - val_loss: 0.1246 - learning_rate: 1.2500e-04
# Epoch 50/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9716 - loss: 0.0948
# Epoch 50: val_accuracy improved from 0.97391 to 0.97826, saving model to best_model.keras
#
# Epoch 50: finished saving model to best_model.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.9667 - loss: 0.1008 - val_accuracy: 0.9783 - val_loss: 0.1113 - learning_rate: 1.2500e-04
# Epoch 51/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9674 - loss: 0.0967
# Epoch 51: val_accuracy did not improve from 0.97826
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.9667 - loss: 0.1076 - val_accuracy: 0.9652 - val_loss: 0.1238 - learning_rate: 1.2500e-04
# Epoch 52/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9774 - loss: 0.0900
# Epoch 52: val_accuracy did not improve from 0.97826
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.9739 - loss: 0.0898 - val_accuracy: 0.9565 - val_loss: 0.1202 - learning_rate: 1.2500e-04
# Epoch 53/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9754 - loss: 0.0816
# Epoch 53: val_accuracy did not improve from 0.97826
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - accuracy: 0.9667 - loss: 0.1020 - val_accuracy: 0.9609 - val_loss: 0.1182 - learning_rate: 1.2500e-04
# Epoch 54/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9743 - loss: 0.0807
# Epoch 54: val_accuracy did not improve from 0.97826
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.9681 - loss: 0.1019 - val_accuracy: 0.9609 - val_loss: 0.1162 - learning_rate: 1.2500e-04
# Epoch 55/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9700 - loss: 0.0772
# Epoch 55: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 55: val_accuracy did not improve from 0.97826
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.9667 - loss: 0.0940 - val_accuracy: 0.9696 - val_loss: 0.1256 - learning_rate: 1.2500e-04
# Epoch 56/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9796 - loss: 0.0773
# Epoch 56: val_accuracy did not improve from 0.97826
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.9783 - loss: 0.0794 - val_accuracy: 0.9696 - val_loss: 0.1131 - learning_rate: 6.2500e-05
# Epoch 57/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9677 - loss: 0.1111
# Epoch 57: val_accuracy did not improve from 0.97826
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.9710 - loss: 0.0989 - val_accuracy: 0.9696 - val_loss: 0.1093 - learning_rate: 6.2500e-05
# Epoch 58/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9610 - loss: 0.1093
# Epoch 58: val_accuracy did not improve from 0.97826
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.9696 - loss: 0.0987 - val_accuracy: 0.9652 - val_loss: 0.1150 - learning_rate: 6.2500e-05
# Epoch 59/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9780 - loss: 0.0929
# Epoch 59: val_accuracy did not improve from 0.97826
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.9768 - loss: 0.0842 - val_accuracy: 0.9739 - val_loss: 0.1064 - learning_rate: 6.2500e-05
# Epoch 60/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9782 - loss: 0.0798
# Epoch 60: val_accuracy did not improve from 0.97826
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.9768 - loss: 0.0873 - val_accuracy: 0.9696 - val_loss: 0.1061 - learning_rate: 6.2500e-05
# Epoch 61/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9697 - loss: 0.0883
# Epoch 61: val_accuracy did not improve from 0.97826
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.9725 - loss: 0.0840 - val_accuracy: 0.9696 - val_loss: 0.1036 - learning_rate: 6.2500e-05
# Epoch 62/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9733 - loss: 0.0938
# Epoch 62: val_accuracy did not improve from 0.97826
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.9710 - loss: 0.0948 - val_accuracy: 0.9696 - val_loss: 0.1083 - learning_rate: 6.2500e-05
# Epoch 63/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9713 - loss: 0.0816
# Epoch 63: val_accuracy did not improve from 0.97826
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.9725 - loss: 0.0876 - val_accuracy: 0.9739 - val_loss: 0.1070 - learning_rate: 6.2500e-05
# Epoch 64/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9750 - loss: 0.0836
# Epoch 64: val_accuracy did not improve from 0.97826
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.9681 - loss: 0.0902 - val_accuracy: 0.9652 - val_loss: 0.1065 - learning_rate: 6.2500e-05
# Epoch 65/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9789 - loss: 0.0728
# Epoch 65: val_accuracy did not improve from 0.97826
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.9768 - loss: 0.0817 - val_accuracy: 0.9696 - val_loss: 0.1171 - learning_rate: 6.2500e-05
# Epoch 66/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9708 - loss: 0.0839
# Epoch 66: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 66: val_accuracy did not improve from 0.97826
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.9739 - loss: 0.0823 - val_accuracy: 0.9609 - val_loss: 0.1177 - learning_rate: 6.2500e-05
# Epoch 67/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9737 - loss: 0.1033
# Epoch 67: val_accuracy did not improve from 0.97826
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.9754 - loss: 0.0893 - val_accuracy: 0.9739 - val_loss: 0.1043 - learning_rate: 3.1250e-05
# Epoch 68/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9708 - loss: 0.0895
# Epoch 68: val_accuracy did not improve from 0.97826
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.9783 - loss: 0.0855 - val_accuracy: 0.9783 - val_loss: 0.1031 - learning_rate: 3.1250e-05
# Epoch 69/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9789 - loss: 0.0896
# Epoch 69: val_accuracy did not improve from 0.97826
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.9812 - loss: 0.0767 - val_accuracy: 0.9696 - val_loss: 0.1057 - learning_rate: 3.1250e-05
# Epoch 70/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9736 - loss: 0.0909
# Epoch 70: val_accuracy did not improve from 0.97826
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.9783 - loss: 0.0784 - val_accuracy: 0.9652 - val_loss: 0.1089 - learning_rate: 3.1250e-05
# Epoch 71/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9646 - loss: 0.0944
# Epoch 71: val_accuracy improved from 0.97826 to 0.98261, saving model to best_model.keras
#
# Epoch 71: finished saving model to best_model.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.9710 - loss: 0.0854 - val_accuracy: 0.9826 - val_loss: 0.0984 - learning_rate: 3.1250e-05
# Epoch 72/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9852 - loss: 0.0561
# Epoch 72: val_accuracy did not improve from 0.98261
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.9826 - loss: 0.0676 - val_accuracy: 0.9652 - val_loss: 0.0986 - learning_rate: 3.1250e-05
# Epoch 73/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9759 - loss: 0.0706
# Epoch 73: val_accuracy did not improve from 0.98261
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.9739 - loss: 0.0861 - val_accuracy: 0.9652 - val_loss: 0.1010 - learning_rate: 3.1250e-05
# Epoch 74/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9882 - loss: 0.0635
# Epoch 74: val_accuracy did not improve from 0.98261
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.9826 - loss: 0.0718 - val_accuracy: 0.9826 - val_loss: 0.0937 - learning_rate: 3.1250e-05
# Epoch 75/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9858 - loss: 0.0707
# Epoch 75: val_accuracy did not improve from 0.98261
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.9812 - loss: 0.0795 - val_accuracy: 0.9652 - val_loss: 0.1011 - learning_rate: 3.1250e-05
# Epoch 76/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9799 - loss: 0.0718
# Epoch 76: val_accuracy did not improve from 0.98261
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.9783 - loss: 0.0796 - val_accuracy: 0.9652 - val_loss: 0.1064 - learning_rate: 3.1250e-05
# Epoch 77/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9772 - loss: 0.0847
# Epoch 77: val_accuracy did not improve from 0.98261
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.9754 - loss: 0.0817 - val_accuracy: 0.9739 - val_loss: 0.1010 - learning_rate: 3.1250e-05
# Epoch 78/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9697 - loss: 0.0913
# Epoch 78: val_accuracy did not improve from 0.98261
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.9710 - loss: 0.0836 - val_accuracy: 0.9652 - val_loss: 0.1010 - learning_rate: 3.1250e-05
# Epoch 79/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9702 - loss: 0.0933
# Epoch 79: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 79: val_accuracy did not improve from 0.98261
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.9783 - loss: 0.0751 - val_accuracy: 0.9783 - val_loss: 0.0946 - learning_rate: 3.1250e-05
# Epoch 80/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9775 - loss: 0.0705
# Epoch 80: val_accuracy did not improve from 0.98261
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.9739 - loss: 0.0794 - val_accuracy: 0.9783 - val_loss: 0.0937 - learning_rate: 1.5625e-05
# Epoch 81/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9795 - loss: 0.0697
# Epoch 81: val_accuracy did not improve from 0.98261
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.9783 - loss: 0.0722 - val_accuracy: 0.9783 - val_loss: 0.0920 - learning_rate: 1.5625e-05
# Epoch 82/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9846 - loss: 0.0667
# Epoch 82: val_accuracy did not improve from 0.98261
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.9826 - loss: 0.0682 - val_accuracy: 0.9739 - val_loss: 0.0932 - learning_rate: 1.5625e-05
# Epoch 83/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9682 - loss: 0.0884
# Epoch 83: val_accuracy did not improve from 0.98261
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.9710 - loss: 0.0914 - val_accuracy: 0.9652 - val_loss: 0.0983 - learning_rate: 1.5625e-05
# Epoch 84/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9826 - loss: 0.0689
# Epoch 84: val_accuracy did not improve from 0.98261
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.9797 - loss: 0.0769 - val_accuracy: 0.9739 - val_loss: 0.0942 - learning_rate: 1.5625e-05
# Epoch 85/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9797 - loss: 0.0593
# Epoch 85: val_accuracy did not improve from 0.98261
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.9725 - loss: 0.0691 - val_accuracy: 0.9739 - val_loss: 0.0947 - learning_rate: 1.5625e-05
# Epoch 86/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9870 - loss: 0.0618
# Epoch 86: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
#
# Epoch 86: val_accuracy did not improve from 0.98261
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.9768 - loss: 0.0736 - val_accuracy: 0.9652 - val_loss: 0.1003 - learning_rate: 1.5625e-05
# Epoch 87/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9727 - loss: 0.0714
# Epoch 87: val_accuracy did not improve from 0.98261
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.9768 - loss: 0.0692 - val_accuracy: 0.9652 - val_loss: 0.0981 - learning_rate: 7.8125e-06
# Epoch 88/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9762 - loss: 0.0603
# Epoch 88: val_accuracy did not improve from 0.98261
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.9783 - loss: 0.0651 - val_accuracy: 0.9739 - val_loss: 0.0946 - learning_rate: 7.8125e-06
# Epoch 89/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9729 - loss: 0.0732
# Epoch 89: val_accuracy did not improve from 0.98261
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.9696 - loss: 0.0800 - val_accuracy: 0.9739 - val_loss: 0.0956 - learning_rate: 7.8125e-06
# Epoch 90/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9779 - loss: 0.0684
# Epoch 90: val_accuracy did not improve from 0.98261
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.9783 - loss: 0.0697 - val_accuracy: 0.9739 - val_loss: 0.0956 - learning_rate: 7.8125e-06
# Epoch 91/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9722 - loss: 0.0975
# Epoch 91: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
#
# Epoch 91: val_accuracy did not improve from 0.98261
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.9768 - loss: 0.0777 - val_accuracy: 0.9783 - val_loss: 0.0941 - learning_rate: 7.8125e-06
# Epoch 92/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9778 - loss: 0.0908
# Epoch 92: val_accuracy did not improve from 0.98261
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.9725 - loss: 0.0851 - val_accuracy: 0.9783 - val_loss: 0.0946 - learning_rate: 3.9063e-06
# Epoch 93/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9797 - loss: 0.0731
# Epoch 93: val_accuracy did not improve from 0.98261
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.9826 - loss: 0.0701 - val_accuracy: 0.9783 - val_loss: 0.0935 - learning_rate: 3.9063e-06
# Epoch 94/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9834 - loss: 0.0695
# Epoch 94: val_accuracy did not improve from 0.98261
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.9768 - loss: 0.0761 - val_accuracy: 0.9783 - val_loss: 0.0927 - learning_rate: 3.9063e-06
# Epoch 95/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9811 - loss: 0.0646
# Epoch 95: val_accuracy did not improve from 0.98261
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.9812 - loss: 0.0745 - val_accuracy: 0.9783 - val_loss: 0.0925 - learning_rate: 3.9063e-06
# Epoch 96/100
# 21/22 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9862 - loss: 0.0661
# Epoch 96: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
#
# Epoch 96: val_accuracy did not improve from 0.98261
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.9841 - loss: 0.0726 - val_accuracy: 0.9783 - val_loss: 0.0937 - learning_rate: 3.9063e-06
# Epoch 96: early stopping
# Restoring model weights from the end of the best epoch: 81.
#
# ✓ Entraînement terminé
# ======================================================================
# MEILLEURS RÉSULTATS
# ======================================================================
# Meilleur epoch : 71
# Train Accuracy : 0.9710
# Val Accuracy : 0.9826
# Train Loss : 0.0854
# Val Loss : 0.0984
#
# ======================================================================
# ÉVALUATION SUR LE JEU DE TEST
# ======================================================================
#
# Test Loss : 0.1134
# Test Accuracy : 0.9697
#
# ======================================================================
# RAPPORT DE CLASSIFICATION
# ======================================================================
#               precision    recall  f1-score   support
#
#           C0       0.98      1.00      0.99       136
#           C1       1.00      0.93      0.96        14
#           C2       1.00      0.83      0.91        12
#           C3       0.85      0.85      0.85        13
#           C4       1.00      1.00      1.00        14
#           C5       0.86      0.86      0.86        14
#           C6       1.00      1.00      1.00        13
#           C7       1.00      1.00      1.00        15
#
#     accuracy                           0.97       231
#    macro avg       0.96      0.93      0.95       231
# weighted avg       0.97      0.97      0.97       231
# ======================================================================
# MÉTRIQUES PAR CLASSE
# ======================================================================
# Classe     Precision    Recall
# -----------------------------------
# C0         0.9784       1.0000
# C1         1.0000       0.9286
# C2         1.0000       0.8333
# C3         0.8462       0.8462
# C4         1.0000       1.0000
# C5         0.8571       0.8571
# C6         1.0000       1.0000
# C7         1.0000       1.0000
#
# ✓ Modèle sauvegardé : lstm_diagnostic_model.keras
#
# ======================================================================
# ENTRAÎNEMENT TERMINÉ AVEC SUCCÈS !
# ======================================================================
